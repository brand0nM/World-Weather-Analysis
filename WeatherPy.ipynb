# %%
# redunadant to use random if we import numpy, random is a package within
import numpy as np
# import random

# %%
# randint(a, b) to get random integer from a range (a,b)
np.random.randint(-90, 90)
# random.randint(-90, 90)
# Out:
# -10

# %%
# get a random number between 0 and 1
np.random.random()
# random.random()
# Out:
# 0.8507151735608781

# %%
# create variable to hold random gcs coordinate (lat, long)
random_gcs = np.random.randint(-90, 90) + np.random.random()
# random_gcs = random.randint(-90, 90) + random.random()
random_gcs
# Out:
# 0.9180099920032636

# %%
# loop through to append a list with coordinates
x = 1
coordinates = []

while x < 11:
    random_gcs = np.random.randint(-90, 90) + np.random.random()
    # random_gcs = random.randint(-90, 90) + random.random()
    coordinates.append(random_gcs)
    x += 1

# %%
coordinates
# Out:
# [-77.34883836051281,
#  -62.255616269596125,
#  -32.82732375413486,
#  40.53012409531564,
#  -59.33536589747331,
#  -23.46139375216823,
#  18.950235569538787,
#  -25.869567902283944,
#  -58.95556599565913,
#  39.84563075631558]

# %%
# default step value is 1, but a 3 will add the range counted by 3's
import random
random.randrange(-90, 90, step = 3)
# Out:
# 21

# %%
random.uniform(-90, 90)
# Out:
# -73.21374868683364

# %%
np.random.uniform(-90, 90)
# Out:
# 53.674022117299614

# %%
np.random.uniform(-90.000, 90.000, size = 50)
# Out:
# array([ 13.19766139,  30.0379933 ,  26.93005736,  -3.90638714,
#         40.17638192, -46.75595957, -39.37619634, -22.96676995,
#         72.60738761,  21.15204382,  89.46643222,  33.16284214,
#        -21.90138127,  17.17109623,  60.91901402,  36.04188253,
#        -40.23753362,  50.74171839, -57.41249049, -62.98529276,
#        -13.06722961,   6.57935763, -68.05204809,  -8.46741009,
#        -85.14449621, -75.70355543,  53.71383547,  66.90628544,
#        -68.21176785,  36.07028143, -74.62306083,  85.48598407,
#         47.25803305, -85.21380208, -30.1299777 , -81.88154956,
#        -78.28461553,  38.56729332, -75.0711891 , -27.38892379,
#        -55.80885254,  11.0115723 ,  46.86062393,  30.47848227,
#         13.81022656, -15.08161427, -29.91391542, -52.32540505,
#        -66.74230754,  40.98344204])

# %%
import timeit
# %timeit np.random.uniform(-90.000, 90.000, size = 1500)
# Out:
# 15.2 µs ± 457 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# create a function thata takes in a size to return an array that size with gcs coordinates
def coordinator(amount):
    coordinates = []
    
    coordinates.append(np.random.uniform(-90.000, 90.000, size = amount))
    
    return coordinates

# %timeit coordinator
# Out:
# 24.1 ns ± 0.734 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
coordinator(50)
# Out:
# [array([-74.79530986,  63.66012895,  -7.3252654 ,  26.44443172,
#          10.39984963, -87.33743742, -22.29988332, -74.94268533,
#         -14.36803201,  19.83060982,  67.70433665, -54.70810246,
#          77.73660253,  84.46376957, -88.99790002, -66.01842162,
#          -9.52233311,  19.9114448 ,  49.70998146,  57.01425998,
#          22.61057223,  35.18809256,  75.26685758, -82.5224435 ,
#          86.69285822,  -6.70499354,  13.06522772,  54.88393117,
#          25.38896397,  89.15613454,  47.00420448,  25.64209476,
#          72.71093149, -80.46227013, -56.2402961 ,  46.48152751,
#           8.89461221,  80.66872131, -28.30562821,  18.44572948,
#          29.6124133 , -21.06005423,   4.91504523,  36.13204628,
#         -89.75357644, -73.47185355, -51.480175  ,  75.73851954,
#         -47.54503266,  24.80686535])]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create the coordinates
lats = np.random.uniform(-90.000, 90.000, size = 1500)
longs = np.random.uniform(-90.000, 90.000, size = 1500)

# zip function allows us to connect these arrays as ordered pairs
gcs_coordinates = zip(lats, longs)

gcs_coordinates

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(gcs_coordinates)

# %%
## pip install citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "9c52aa93220062a382edb4a8caedfa3a"

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c52aa93220062a382edb4a8caedfa3a&q=Boston

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":68.38,"feels_like":66.7,"temp_min":62.67,"temp_max":71.08,"pressure":1011,"humidity":38},"visibility":10000,"wind":{"speed":24.16,"deg":200,"gust":29.93},"clouds":{"all":100},"dt":1650131626,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1650103290,"sunset":1650151567},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 68.38,
#   'feels_like': 66.7,
#   'temp_min': 62.67,
#   'temp_max': 71.08,
#   'pressure': 1011,
#   'humidity': 38},
#  'visibility': 10000,
#  'wind': {'speed': 24.16, 'deg': 200, 'gust': 29.93},
#  'clouds': {'all': 100},
#  'dt': 1650131626,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1650103290,
#   'sunset': 1650151567},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 68.38,
#   'feels_like': 66.7,
#   'temp_min': 62.67,
#   'temp_max': 71.08,
#   'pressure': 1011,
#   'humidity': 38},
#  'visibility': 10000,
#  'wind': {'speed': 24.16, 'deg': 200, 'gust': 29.93},
#  'clouds': {'all': 100},
#  'dt': 1650131626,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1650103290,
#   'sunset': 1650151567},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Get the JSON data.
boston_data["sys"]
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1650103290,
#  'sunset': 1650151567}

# %%
boston_data["dt"]
# Out:
# 1650131626

# %%
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 71.08 38 100 24.16

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 4, 16, 17, 53, 46)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-04-16 17:53:46'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
#city_data = []

# Print the beginning of the logging.
#print("Beginning Data Retrieval     ")
#print("-----------------------------")

# Create counters.
#record_count = 1
#set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    #if (i % 50 == 0 and i >= 50):
        #set_count += 1
        #record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    #city_url = url + "&q=" + cities[i]

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60) # stop any opperations for 60 seconds

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
    # Add 1 to the record count.
    record_count += 1
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# try:
  # Do something
# except:
  # print("An exception occurred")

# %%
city_data
# Out:
# [{'City': 'Kribi',
#   'Lat': 2.95,
#   'Lng': 9.9167,
#   'Max Temp': 80.69,
#   'Humidity': 85,
#   'Cloudiness': 83,
#   'Wind Speed': 10.18,
#   'Country': 'CM',
#   'Date': '2022-04-16 17:57:12'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 59.95,
#   'Humidity': 82,
#   'Cloudiness': 13,
#   'Wind Speed': 6.91,
#   'Country': 'NA',
#   'Date': '2022-04-16 17:57:13'},
#  {'City': 'Abalak',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 41.04,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 11.27,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:57:13'},
#  {'City': 'Bar-Le-Duc',
#   'Lat': 48.75,
#   'Lng': 5.1667,
#   'Max Temp': 61.18,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 12.73,
#   'Country': 'FR',
#   'Date': '2022-04-16 17:57:14'},
#  {'City': 'Kibaya',
#   'Lat': -5.3,
#   'Lng': 36.5667,
#   'Max Temp': 59.85,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.81,
#   'Country': 'TZ',
#   'Date': '2022-04-16 17:57:14'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.59,
#   'Humidity': 80,
#   'Cloudiness': 51,
#   'Wind Speed': 14.25,
#   'Country': 'RE',
#   'Date': '2022-04-16 17:48:00'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 47.07,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 21.54,
#   'Country': 'NO',
#   'Date': '2022-04-16 17:57:14'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.52,
#   'Humidity': 65,
#   'Cloudiness': 96,
#   'Wind Speed': 3.74,
#   'Country': 'MV',
#   'Date': '2022-04-16 17:57:15'},
#  {'City': 'Ginir',
#   'Lat': 7.1333,
#   'Lng': 40.7,
#   'Max Temp': 61.05,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 5.48,
#   'Country': 'ET',
#   'Date': '2022-04-16 17:57:15'},
#  {'City': 'Puerto Madryn',
#   'Lat': -42.7692,
#   'Lng': -65.0385,
#   'Max Temp': 62.71,
#   'Humidity': 44,
#   'Cloudiness': 2,
#   'Wind Speed': 12.5,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:57:16'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 18.41,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.52,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:57:16'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 62.31,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:53:42'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 85.68,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Country': 'GD',
#   'Date': '2022-04-16 17:55:13'},
#  {'City': 'Kpandu',
#   'Lat': 6.9954,
#   'Lng': 0.2931,
#   'Max Temp': 80.08,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 4.12,
#   'Country': 'GH',
#   'Date': '2022-04-16 17:57:17'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.18,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:57:17'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 70.57,
#   'Humidity': 58,
#   'Cloudiness': 89,
#   'Wind Speed': 11.92,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:57:17'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.26,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:57:18'},
#  {'City': 'Putina',
#   'Lat': -15.4667,
#   'Lng': -69.4333,
#   'Max Temp': 49.26,
#   'Humidity': 31,
#   'Cloudiness': 10,
#   'Wind Speed': 4.43,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:57:18'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 64.45,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:49:19'},
#  {'City': 'Mutis',
#   'Lat': 6.2262,
#   'Lng': -77.4044,
#   'Max Temp': 81.75,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.64,
#   'Country': 'CO',
#   'Date': '2022-04-16 17:57:19'},
#  {'City': 'Japura',
#   'Lat': -0.3167,
#   'Lng': 102.35,
#   'Max Temp': 75.2,
#   'Humidity': 97,
#   'Cloudiness': 95,
#   'Wind Speed': 1.61,
#   'Country': 'ID',
#   'Date': '2022-04-16 17:57:19'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 13.1,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.72,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:57:19'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 72.18,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 15.99,
#   'Country': 'HK',
#   'Date': '2022-04-16 17:47:52'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.8,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 20.09,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:57:20'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 60.58,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 13.73,
#   'Country': 'CL',
#   'Date': '2022-04-16 17:57:20'},
#  {'City': 'Chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 63.14,
#   'Humidity': 61,
#   'Cloudiness': 18,
#   'Wind Speed': 10.65,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:57:21'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 71.64,
#   'Humidity': 72,
#   'Cloudiness': 81,
#   'Wind Speed': 11.81,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:53:16'},
#  {'City': 'Norden',
#   'Lat': 53.6,
#   'Lng': 7.2,
#   'Max Temp': 55.38,
#   'Humidity': 70,
#   'Cloudiness': 74,
#   'Wind Speed': 7.45,
#   'Country': 'DE',
#   'Date': '2022-04-16 17:57:21'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 80.2,
#   'Humidity': 84,
#   'Cloudiness': 55,
#   'Wind Speed': 3.27,
#   'Country': 'LK',
#   'Date': '2022-04-16 17:57:22'},
#  {'City': 'Lyuban',
#   'Lat': 52.7985,
#   'Lng': 28.0048,
#   'Max Temp': 36.55,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 15.79,
#   'Country': 'BY',
#   'Date': '2022-04-16 17:57:22'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 75.69,
#   'Humidity': 78,
#   'Cloudiness': 25,
#   'Wind Speed': 4.54,
#   'Country': 'MG',
#   'Date': '2022-04-16 17:57:23'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 68.02,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:46:50'},
#  {'City': 'Svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 39.25,
#   'Humidity': 78,
#   'Cloudiness': 26,
#   'Wind Speed': 12.57,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:57:23'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 29.03,
#   'Humidity': 71,
#   'Cloudiness': 4,
#   'Wind Speed': 18.92,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:57:23'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 46.18,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 13,
#   'Country': 'US',
#   'Date': '2022-04-16 17:54:49'},
#  {'City': 'Koson',
#   'Lat': 39.0375,
#   'Lng': 65.585,
#   'Max Temp': 70.12,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Country': 'UZ',
#   'Date': '2022-04-16 17:57:24'},
#  {'City': 'Tashtyp',
#   'Lat': 52.7939,
#   'Lng': 89.8983,
#   'Max Temp': 44.69,
#   'Humidity': 71,
#   'Cloudiness': 25,
#   'Wind Speed': 3.47,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:57:24'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 46.04,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.22,
#   'Country': 'GB',
#   'Date': '2022-04-16 17:57:25'},
#  {'City': 'West Bay',
#   'Lat': 19.3667,
#   'Lng': -81.4167,
#   'Max Temp': 86.07,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'KY',
#   'Date': '2022-04-16 17:57:25'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 40.75,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 33.38,
#   'Country': 'NO',
#   'Date': '2022-04-16 17:57:26'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 69.01,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:50:35'},
#  {'City': 'Den Helder',
#   'Lat': 52.9599,
#   'Lng': 4.7593,
#   'Max Temp': 57.18,
#   'Humidity': 40,
#   'Cloudiness': 70,
#   'Wind Speed': 14,
#   'Country': 'NL',
#   'Date': '2022-04-16 17:57:26'},
#  {'City': 'Tismana',
#   'Lat': 45.05,
#   'Lng': 22.9667,
#   'Max Temp': 51.87,
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 3.6,
#   'Country': 'RO',
#   'Date': '2022-04-16 17:57:26'},
#  {'City': 'Lalibela',
#   'Lat': 12.0333,
#   'Lng': 39.0333,
#   'Max Temp': 65.68,
#   'Humidity': 47,
#   'Cloudiness': 89,
#   'Wind Speed': 5.7,
#   'Country': 'ET',
#   'Date': '2022-04-16 17:57:27'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 59.49,
#   'Humidity': 69,
#   'Cloudiness': 22,
#   'Wind Speed': 14.74,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:57:27'},
#  {'City': 'Amapa',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 84.04,
#   'Humidity': 69,
#   'Cloudiness': 88,
#   'Wind Speed': 4.41,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:53:08'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.8,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'PT',
#   'Date': '2022-04-16 17:49:25'},
#  {'City': 'Iberia',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp': 81.97,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2022-04-16 17:58:28'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.81,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:58:28'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 76.08,
#   'Humidity': 74,
#   'Cloudiness': 32,
#   'Wind Speed': 21.36,
#   'Country': 'GW',
#   'Date': '2022-04-16 17:51:47'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64.65,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 6.13,
#   'Country': 'PT',
#   'Date': '2022-04-16 17:58:29'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77.07,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2022-04-16 17:55:43'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.16,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:55:56'},
#  {'City': 'Mormugao',
#   'Lat': 15.4,
#   'Lng': 73.8,
#   'Max Temp': 79.86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2022-04-16 17:54:28'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 68.2,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 13.8,
#   'Country': 'EG',
#   'Date': '2022-04-16 17:58:30'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 62.33,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'CL',
#   'Date': '2022-04-16 17:46:43'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 59.94,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:53:32'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 80.64,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'IN',
#   'Date': '2022-04-16 17:58:31'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 80.56,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'TC',
#   'Date': '2022-04-16 17:54:36'},
#  {'City': 'Bay Roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 57.51,
#   'Humidity': 56,
#   'Cloudiness': 51,
#   'Wind Speed': 10,
#   'Country': 'CA',
#   'Date': '2022-04-16 17:58:31'},
#  {'City': 'Apam',
#   'Lat': 5.2848,
#   'Lng': -0.7371,
#   'Max Temp': 76.71,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.22,
#   'Country': 'GH',
#   'Date': '2022-04-16 17:58:32'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.33,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Date': '2022-04-16 17:45:17'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 32.14,
#   'Humidity': 78,
#   'Cloudiness': 6,
#   'Wind Speed': 11.68,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:58:32'},
#  {'City': 'Miraflores',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 79.45,
#   'Humidity': 30,
#   'Cloudiness': 14,
#   'Wind Speed': 4.59,
#   'Country': 'MX',
#   'Date': '2022-04-16 17:53:20'},
#  {'City': 'Vondrozo',
#   'Lat': -22.8167,
#   'Lng': 47.2833,
#   'Max Temp': 68.09,
#   'Humidity': 97,
#   'Cloudiness': 81,
#   'Wind Speed': 2.55,
#   'Country': 'MG',
#   'Date': '2022-04-16 17:58:33'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 73.44,
#   'Humidity': 75,
#   'Cloudiness': 68,
#   'Wind Speed': 10.67,
#   'Country': 'AO',
#   'Date': '2022-04-16 17:51:56'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 81.66,
#   'Humidity': 79,
#   'Cloudiness': 68,
#   'Wind Speed': 7.58,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:52:04'},
#  {'City': 'Hurghada',
#   'Lat': 27.2574,
#   'Lng': 33.8129,
#   'Max Temp': 86.04,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'EG',
#   'Date': '2022-04-16 17:58:33'},
#  {'City': 'Moissala',
#   'Lat': 8.3404,
#   'Lng': 17.7663,
#   'Max Temp': 93.42,
#   'Humidity': 27,
#   'Cloudiness': 67,
#   'Wind Speed': 1.88,
#   'Country': 'TD',
#   'Date': '2022-04-16 17:58:34'},
#  {'City': 'Caceres',
#   'Lat': 39.522,
#   'Lng': -6.3748,
#   'Max Temp': 73.06,
#   'Humidity': 53,
#   'Cloudiness': 8,
#   'Wind Speed': 6.46,
#   'Country': 'ES',
#   'Date': '2022-04-16 17:58:34'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -4.43,
#   'Humidity': 86,
#   'Cloudiness': 61,
#   'Wind Speed': 16.4,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:54:44'},
#  {'City': 'Jablunka',
#   'Lat': 49.3835,
#   'Lng': 17.9502,
#   'Max Temp': 46.62,
#   'Humidity': 58,
#   'Cloudiness': 39,
#   'Wind Speed': 10,
#   'Country': 'CZ',
#   'Date': '2022-04-16 17:58:35'},
#  {'City': 'Maarianhamina',
#   'Lat': 60.0973,
#   'Lng': 19.9348,
#   'Max Temp': 39.06,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AX',
#   'Date': '2022-04-16 17:58:35'},
#  {'City': 'Barranca',
#   'Lat': -10.75,
#   'Lng': -77.7667,
#   'Max Temp': 69.42,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 10.85,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:58:36'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 59.97,
#   'Humidity': 69,
#   'Cloudiness': 73,
#   'Wind Speed': 8.43,
#   'Country': 'PT',
#   'Date': '2022-04-16 17:58:36'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 88.07,
#   'Humidity': 44,
#   'Cloudiness': 5,
#   'Wind Speed': 6.02,
#   'Country': 'OM',
#   'Date': '2022-04-16 17:58:36'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77.29,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MU',
#   'Date': '2022-04-16 17:50:46'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 72.23,
#   'Humidity': 21,
#   'Cloudiness': 29,
#   'Wind Speed': 8.43,
#   'Country': 'NP',
#   'Date': '2022-04-16 17:58:37'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 67.51,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'UY',
#   'Date': '2022-04-16 17:54:45'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 82.24,
#   'Humidity': 16,
#   'Cloudiness': 38,
#   'Wind Speed': 4.94,
#   'Country': 'MA',
#   'Date': '2022-04-16 17:58:38'},
#  {'City': 'Rio Cuarto',
#   'Lat': -33.1307,
#   'Lng': -64.3499,
#   'Max Temp': 75.47,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:58:38'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 84.24,
#   'Humidity': 1,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'GF',
#   'Date': '2022-04-16 17:58:38'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 37.62,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 17.47,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:58:39'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 95.22,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 7.43,
#   'Country': 'CR',
#   'Date': '2022-04-16 17:54:34'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 62.46,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:50:31'},
#  {'City': 'Verkhnyaya Maksakovka',
#   'Lat': 61.635,
#   'Lng': 50.9674,
#   'Max Temp': 32.02,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:58:39'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 17.62,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:49:19'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 38.93,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-04-16 17:55:54'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 84.18,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 7.43,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:58:40'},
#  {'City': 'Nangwa',
#   'Lat': -4.4667,
#   'Lng': 35.45,
#   'Max Temp': 58.15,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'TZ',
#   'Date': '2022-04-16 17:58:40'},
#  {'City': 'Kaduqli',
#   'Lat': 11.0167,
#   'Lng': 29.7167,
#   'Max Temp': 91.22,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Country': 'SD',
#   'Date': '2022-04-16 17:58:41'},
#  {'City': 'Sikonge',
#   'Lat': -5.6333,
#   'Lng': 32.7667,
#   'Max Temp': 66.18,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 1.03,
#   'Country': 'TZ',
#   'Date': '2022-04-16 17:58:50'},
#  {'City': 'Bergama',
#   'Lat': 39.1207,
#   'Lng': 27.1805,
#   'Max Temp': 62.29,
#   'Humidity': 56,
#   'Cloudiness': 79,
#   'Wind Speed': 1.14,
#   'Country': 'TR',
#   'Date': '2022-04-16 17:59:41'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -8.01,
#   'Humidity': 75,
#   'Cloudiness': 69,
#   'Wind Speed': 6.35,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:59:42'},
#  {'City': 'Mopipi',
#   'Lat': -21.1833,
#   'Lng': 24.8833,
#   'Max Temp': 69.76,
#   'Humidity': 76,
#   'Cloudiness': 85,
#   'Wind Speed': 19.95,
#   'Country': 'BW',
#   'Date': '2022-04-16 17:59:42'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 65.48,
#   'Humidity': 70,
#   'Cloudiness': 12,
#   'Wind Speed': 8.43,
#   'Country': 'CL',
#   'Date': '2022-04-16 17:59:42'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 83.35,
#   'Humidity': 73,
#   'Cloudiness': 66,
#   'Wind Speed': 15.32,
#   'Country': 'SO',
#   'Date': '2022-04-16 17:51:57'},
#  {'City': 'Sidi Ali',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 59.43,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 3.91,
#   'Country': 'DZ',
#   'Date': '2022-04-16 17:59:43'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 77.38,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MU',
#   'Date': '2022-04-16 17:59:43'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 33.53,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 4.5,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:59:44'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 84.42,
#   'Humidity': 72,
#   'Cloudiness': 28,
#   'Wind Speed': 3.8,
#   'Country': 'IN',
#   'Date': '2022-04-16 17:59:44'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 59.68,
#   'Humidity': 48,
#   'Cloudiness': 60,
#   'Wind Speed': 13.44,
#   'Country': 'US',
#   'Date': '2022-04-16 17:55:51'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 82.36,
#   'Humidity': 78,
#   'Cloudiness': 53,
#   'Wind Speed': 10.58,
#   'Country': 'SO',
#   'Date': '2022-04-16 17:59:45'},
#  {'City': 'Lodwar',
#   'Lat': 3.1191,
#   'Lng': 35.5973,
#   'Max Temp': 82.02,
#   'Humidity': 57,
#   'Cloudiness': 88,
#   'Wind Speed': 9.24,
#   'Country': 'KE',
#   'Date': '2022-04-16 17:59:45'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.48,
#   'Humidity': 77,
#   'Cloudiness': 82,
#   'Wind Speed': 11.23,
#   'Country': 'AU',
#   'Date': '2022-04-16 17:59:46'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 89.04,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:52:31'},
#  {'City': 'Moyale',
#   'Lat': 3.5167,
#   'Lng': 39.0584,
#   'Max Temp': 73.44,
#   'Humidity': 59,
#   'Cloudiness': 99,
#   'Wind Speed': 2.24,
#   'Country': 'KE',
#   'Date': '2022-04-16 17:50:34'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 36.34,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 2.64,
#   'Country': 'GL',
#   'Date': '2022-04-16 17:50:44'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 78.91,
#   'Humidity': 54,
#   'Cloudiness': 98,
#   'Wind Speed': 6.71,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:50:43'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 69.84,
#   'Humidity': 46,
#   'Cloudiness': 7,
#   'Wind Speed': 14.41,
#   'Country': 'AR',
#   'Date': '2022-04-16 17:59:46'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2022-04-16 17:59:40'},
#  {'City': 'Mapiri',
#   'Lat': -15.25,
#   'Lng': -68.1667,
#   'Max Temp': 80.33,
#   'Humidity': 56,
#   'Cloudiness': 91,
#   'Wind Speed': 1.68,
#   'Country': 'BO',
#   'Date': '2022-04-16 17:59:47'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 87.82,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AE',
#   'Date': '2022-04-16 17:57:51'},
#  {'City': 'Piacabucu',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 86.09,
#   'Humidity': 67,
#   'Cloudiness': 33,
#   'Wind Speed': 13.62,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:53:17'},
#  {'City': 'Asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 89.78,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 6.11,
#   'Country': 'EG',
#   'Date': '2022-04-16 17:59:48'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 57.11,
#   'Humidity': 80,
#   'Cloudiness': 3,
#   'Wind Speed': 4,
#   'Country': 'GB',
#   'Date': '2022-04-16 17:59:48'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 59.65,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2022-04-16 17:53:40'},
#  {'City': 'Knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 59.34,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 9.62,
#   'Country': 'ZA',
#   'Date': '2022-04-16 17:59:49'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 76.23,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'GH',
#   'Date': '2022-04-16 17:57:11'},
#  {'City': 'Mahanoro',
#   'Lat': -19.9,
#   'Lng': 48.8,
#   'Max Temp': 75.36,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 2.53,
#   'Country': 'MG',
#   'Date': '2022-04-16 17:59:49'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 78.19,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.61,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:59:50'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 87.53,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Date': '2022-04-16 17:50:05'},
#  {'City': 'Barraute',
#   'Lat': 48.4335,
#   'Lng': -77.6328,
#   'Max Temp': 32.27,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Country': 'CA',
#   'Date': '2022-04-16 17:59:50'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 94.23,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Country': 'MR',
#   'Date': '2022-04-16 17:59:51'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 78.71,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.46,
#   'Country': 'SA',
#   'Date': '2022-04-16 17:59:51'},
#  {'City': 'Loukhi',
#   'Lat': 66.0764,
#   'Lng': 33.0381,
#   'Max Temp': 31.84,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 6.62,
#   'Country': 'RU',
#   'Date': '2022-04-16 17:59:51'},
#  {'City': 'Kirkenaer',
#   'Lat': 60.4564,
#   'Lng': 12.0582,
#   'Max Temp': 45.23,
#   'Humidity': 86,
#   'Cloudiness': 35,
#   'Wind Speed': 0.94,
#   'Country': 'NO',
#   'Date': '2022-04-16 17:59:52'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 59.61,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2022-04-16 17:59:52'},
#  {'City': 'Roanoke Rapids',
#   'Lat': 36.4615,
#   'Lng': -77.6542,
#   'Max Temp': 71.02,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2022-04-16 17:59:53'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 56.75,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Country': 'CA',
#   'Date': '2022-04-16 17:59:53'},
#  {'City': 'Ankazoabo',
#   'Lat': -22.2833,
#   'Lng': 44.5167,
#   'Max Temp': 79.83,
#   'Humidity': 56,
#   'Cloudiness': 61,
#   'Wind Speed': 7.23,
#   'Country': 'MG',
#   'Date': '2022-04-16 17:59:53'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 65.62,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'PT',
#   'Date': '2022-04-16 17:50:35'},
#  {'City': 'Punta Cardon',
#   'Lat': 11.6581,
#   'Lng': -70.215,
#   'Max Temp': 84,
#   'Humidity': 66,
#   'Cloudiness': 7,
#   'Wind Speed': 28.61,
#   'Country': 'VE',
#   'Date': '2022-04-16 17:59:54'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 39.13,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 23.55,
#   'Country': 'NO',
#   'Date': '2022-04-16 17:59:54'},
#  {'City': 'Sergeyevka',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': 49.95,
#   'Humidity': 57,
#   'Cloudiness': 97,
#   'Wind Speed': 6.29,
#   'Country': 'KZ',
#   'Date': '2022-04-16 17:59:55'},
#  {'City': 'Bako',
#   'Lat': 5.7833,
#   'Lng': 36.5667,
#   'Max Temp': 64.18,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 2.82,
#   'Country': 'ET',
#   'Date': '2022-04-16 17:59:55'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 80.62,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 9.73,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:00:56'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 32.72,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:00:56'},
#  {'City': 'Pafos',
#   'Lat': 34.7667,
#   'Lng': 32.4167,
#   'Max Temp': 65.98,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CY',
#   'Date': '2022-04-16 18:00:57'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -5.15,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:00:58'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 26.44,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'SJ',
#   'Date': '2022-04-16 18:00:58'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 63.05,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-04-16 18:00:59'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 52.48,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'CN',
#   'Date': '2022-04-16 17:54:25'},
#  {'City': 'Santa Maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 69.66,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 6.85,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:00:59'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 46.18,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13,
#   'Country': 'IS',
#   'Date': '2022-04-16 17:50:50'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 30.88,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.55,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:01:00'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 94.98,
#   'Humidity': 7,
#   'Cloudiness': 61,
#   'Wind Speed': 8.72,
#   'Country': 'NE',
#   'Date': '2022-04-16 18:01:00'},
#  {'City': 'Samana',
#   'Lat': 19.2056,
#   'Lng': -69.3369,
#   'Max Temp': 83.43,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 12.21,
#   'Country': 'DO',
#   'Date': '2022-04-16 18:01:01'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 75.58,
#   'Humidity': 80,
#   'Cloudiness': 45,
#   'Wind Speed': 14.61,
#   'Country': 'RE',
#   'Date': '2022-04-16 18:01:01'},
#  {'City': 'Kyzyl-Suu',
#   'Lat': 42.3414,
#   'Lng': 78.0056,
#   'Max Temp': 49.39,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Country': 'KG',
#   'Date': '2022-04-16 18:01:02'},
#  {'City': 'Bojnurd',
#   'Lat': 37.4747,
#   'Lng': 57.329,
#   'Max Temp': 46.35,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'IR',
#   'Date': '2022-04-16 17:57:41'},
#  {'City': 'Khislavichi',
#   'Lat': 54.1871,
#   'Lng': 32.1582,
#   'Max Temp': 35.42,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.96,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:01:02'},
#  {'City': 'Luau',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 67.33,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.01,
#   'Country': 'AO',
#   'Date': '2022-04-16 18:01:03'},
#  {'City': 'Copiapo',
#   'Lat': -27.3667,
#   'Lng': -70.3333,
#   'Max Temp': 77.34,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 8.1,
#   'Country': 'CL',
#   'Date': '2022-04-16 18:00:32'},
#  {'City': 'Konstancin-Jeziorna',
#   'Lat': 52.0938,
#   'Lng': 21.1176,
#   'Max Temp': 48.11,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'PL',
#   'Date': '2022-04-16 17:59:37'},
#  {'City': 'Wildberg',
#   'Lat': 48.6234,
#   'Lng': 8.7452,
#   'Max Temp': 53.46,
#   'Humidity': 68,
#   'Cloudiness': 10,
#   'Wind Speed': 8.52,
#   'Country': 'DE',
#   'Date': '2022-04-16 18:01:04'},
#  {'City': 'Tomaszow Mazowiecki',
#   'Lat': 51.5313,
#   'Lng': 20.0086,
#   'Max Temp': 47.55,
#   'Humidity': 61,
#   'Cloudiness': 67,
#   'Wind Speed': 7.54,
#   'Country': 'PL',
#   'Date': '2022-04-16 18:01:04'},
#  {'City': 'Umm Kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 88.12,
#   'Humidity': 7,
#   'Cloudiness': 99,
#   'Wind Speed': 12.41,
#   'Country': 'SD',
#   'Date': '2022-04-16 18:01:05'},
#  {'City': 'Usevya',
#   'Lat': -7.1,
#   'Lng': 31.2333,
#   'Max Temp': 68.07,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 2.82,
#   'Country': 'TZ',
#   'Date': '2022-04-16 17:58:43'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 75.25,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:56:09'},
#  {'City': 'Santiago Del Estero',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp': 75.92,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'AR',
#   'Date': '2022-04-16 18:01:06'},
#  {'City': 'Breves',
#   'Lat': -1.6822,
#   'Lng': -50.4803,
#   'Max Temp': 81.86,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 3.65,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:01:06'},
#  {'City': 'Uniao',
#   'Lat': -4.5858,
#   'Lng': -42.8642,
#   'Max Temp': 84.94,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 1.41,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:01:07'},
#  {'City': 'Agirish',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp': 27.55,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:01:07'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 79.34,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Country': 'CV',
#   'Date': '2022-04-16 17:53:19'},
#  {'City': 'Salta',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Max Temp': 71.58,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'AR',
#   'Date': '2022-04-16 18:00:37'},
#  {'City': 'Umea',
#   'Lat': 63.8284,
#   'Lng': 20.2597,
#   'Max Temp': 39.13,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'SE',
#   'Date': '2022-04-16 18:01:08'},
#  {'City': 'Sao Geraldo Do Araguaia',
#   'Lat': -6.4006,
#   'Lng': -48.555,
#   'Max Temp': 82.78,
#   'Humidity': 83,
#   'Cloudiness': 38,
#   'Wind Speed': 3.76,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:01:09'},
#  {'City': 'Villarrica',
#   'Lat': -25.75,
#   'Lng': -56.4333,
#   'Max Temp': 75.72,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'PY',
#   'Date': '2022-04-16 18:01:09'},
#  {'City': 'Sassandra',
#   'Lat': 4.95,
#   'Lng': -6.0833,
#   'Max Temp': 79.92,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 8.72,
#   'Country': 'CI',
#   'Date': '2022-04-16 18:01:10'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 5,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2022-04-16 17:51:57'},
#  {'City': 'Mgandu',
#   'Lat': -5.95,
#   'Lng': 34.1333,
#   'Max Temp': 61.66,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 5.73,
#   'Country': 'TZ',
#   'Date': '2022-04-16 18:01:10'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 16.68,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:01:11'},
#  {'City': 'Wasaga Beach',
#   'Lat': 44.5168,
#   'Lng': -80.0164,
#   'Max Temp': 41.47,
#   'Humidity': 80,
#   'Cloudiness': 63,
#   'Wind Speed': 1.01,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:00:03'},
#  {'City': 'Mochudi',
#   'Lat': -24.4167,
#   'Lng': 26.15,
#   'Max Temp': 61.88,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 12.44,
#   'Country': 'BW',
#   'Date': '2022-04-16 18:01:11'},
#  {'City': 'San Francisco',
#   'Lat': 37.7749,
#   'Lng': -122.4194,
#   'Max Temp': 62.22,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-04-16 17:59:52'},
#  {'City': 'Acari',
#   'Lat': -15.4311,
#   'Lng': -74.6158,
#   'Max Temp': 77.85,
#   'Humidity': 56,
#   'Cloudiness': 99,
#   'Wind Speed': 10.27,
#   'Country': 'PE',
#   'Date': '2022-04-16 18:01:12'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 24.82,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 5.84,
#   'Country': 'GL',
#   'Date': '2022-04-16 18:01:12'},
#  {'City': 'Kharabali',
#   'Lat': 47.4196,
#   'Lng': 47.2568,
#   'Max Temp': 59.54,
#   'Humidity': 51,
#   'Cloudiness': 61,
#   'Wind Speed': 8.25,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:01:13'},
#  {'City': 'Aiquile',
#   'Lat': -18.2041,
#   'Lng': -65.1807,
#   'Max Temp': 64.02,
#   'Humidity': 61,
#   'Cloudiness': 93,
#   'Wind Speed': 9.98,
#   'Country': 'BO',
#   'Date': '2022-04-16 18:01:13'},
#  {'City': 'Sierpc',
#   'Lat': 52.8568,
#   'Lng': 19.6691,
#   'Max Temp': 39.88,
#   'Humidity': 59,
#   'Cloudiness': 56,
#   'Wind Speed': 13.53,
#   'Country': 'PL',
#   'Date': '2022-04-16 18:01:13'},
#  {'City': 'Libourne',
#   'Lat': 44.9167,
#   'Lng': -0.25,
#   'Max Temp': 72.1,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 8.93,
#   'Country': 'FR',
#   'Date': '2022-04-16 18:01:14'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 83.8,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 12.84,
#   'Country': 'GH',
#   'Date': '2022-04-16 18:02:14'},
#  {'City': 'Ferrol',
#   'Lat': 43.4832,
#   'Lng': -8.2369,
#   'Max Temp': 60.71,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 2.13,
#   'Country': 'ES',
#   'Date': '2022-04-16 18:02:15'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 75.43,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 13,
#   'Country': 'US',
#   'Date': '2022-04-16 18:02:15'},
#  {'City': 'Nawa',
#   'Lat': 27.0167,
#   'Lng': 75,
#   'Max Temp': 84.38,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 6.4,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:02:16'},
#  {'City': 'Balsas',
#   'Lat': -7.5325,
#   'Lng': -46.0356,
#   'Max Temp': 89.13,
#   'Humidity': 54,
#   'Cloudiness': 33,
#   'Wind Speed': 1.57,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:02:16'},
#  {'City': 'Puteyets',
#   'Lat': 65.1716,
#   'Lng': 57.091,
#   'Max Temp': 11.89,
#   'Humidity': 95,
#   'Cloudiness': 74,
#   'Wind Speed': 4.56,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:02:16'},
#  {'City': 'Tahta',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 88.79,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Country': 'EG',
#   'Date': '2022-04-16 18:02:17'},
#  {'City': 'Uvinza',
#   'Lat': -5.1036,
#   'Lng': 30.3911,
#   'Max Temp': 66.49,
#   'Humidity': 96,
#   'Cloudiness': 58,
#   'Wind Speed': 1.48,
#   'Country': 'TZ',
#   'Date': '2022-04-16 18:02:17'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 29.01,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'GL',
#   'Date': '2022-04-16 18:02:17'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 65.64,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'FR',
#   'Date': '2022-04-16 18:02:18'},
#  {'City': 'Matay',
#   'Lat': 28.419,
#   'Lng': 30.7792,
#   'Max Temp': 85.57,
#   'Humidity': 10,
#   'Cloudiness': 2,
#   'Wind Speed': 6.22,
#   'Country': 'EG',
#   'Date': '2022-04-16 18:02:18'},
#  {'City': 'Khalkhal',
#   'Lat': 37.6189,
#   'Lng': 48.5258,
#   'Max Temp': 34.32,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.59,
#   'Country': 'IR',
#   'Date': '2022-04-16 18:02:19'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 5.7,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:02:19'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 66.22,
#   'Humidity': 68,
#   'Cloudiness': 29,
#   'Wind Speed': 4.81,
#   'Country': 'CL',
#   'Date': '2022-04-16 18:02:19'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 81.1,
#   'Humidity': 75,
#   'Cloudiness': 54,
#   'Wind Speed': 7.54,
#   'Country': 'PH',
#   'Date': '2022-04-16 18:02:20'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 66.61,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Country': 'PT',
#   'Date': '2022-04-16 17:57:29'},
#  {'City': 'Rampur Hat',
#   'Lat': 24.1667,
#   'Lng': 87.7833,
#   'Max Temp': 84.76,
#   'Humidity': 68,
#   'Cloudiness': 27,
#   'Wind Speed': 10,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:02:20'},
#  {'City': 'Pangoa',
#   'Lat': -12.1167,
#   'Lng': -73,
#   'Max Temp': 84.15,
#   'Humidity': 51,
#   'Cloudiness': 99,
#   'Wind Speed': 4.34,
#   'Country': 'PE',
#   'Date': '2022-04-16 17:53:19'},
#  {'City': 'Kabinda',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp': 71.44,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 2.89,
#   'Country': 'CD',
#   'Date': '2022-04-16 18:02:21'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 72.39,
#   'Humidity': 100,
#   'Cloudiness': 39,
#   'Wind Speed': 6.13,
#   'Country': 'IL',
#   'Date': '2022-04-16 17:58:01'},
#  {'City': 'Elliot Lake',
#   'Lat': 46.3834,
#   'Lng': -82.6331,
#   'Max Temp': 32.23,
#   'Humidity': 58,
#   'Cloudiness': 92,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:02:21'},
#  {'City': 'Bad Freienwalde',
#   'Lat': 52.7873,
#   'Lng': 14.0304,
#   'Max Temp': 48.42,
#   'Humidity': 47,
#   'Cloudiness': 50,
#   'Wind Speed': 4,
#   'Country': 'DE',
#   'Date': '2022-04-16 18:02:22'},
#  {'City': 'Shu',
#   'Lat': 43.5983,
#   'Lng': 73.7614,
#   'Max Temp': 62.92,
#   'Humidity': 34,
#   'Cloudiness': 49,
#   'Wind Speed': 5.97,
#   'Country': 'KZ',
#   'Date': '2022-04-16 17:55:44'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 80.98,
#   'Humidity': 80,
#   'Cloudiness': 60,
#   'Wind Speed': 1.52,
#   'Country': 'ID',
#   'Date': '2022-04-16 18:02:22'},
#  {'City': 'Adeje',
#   'Lat': 28.1227,
#   'Lng': -16.726,
#   'Max Temp': 77.86,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'ES',
#   'Date': '2022-04-16 18:02:23'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 31.78,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 11.68,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:02:23'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 85.77,
#   'Humidity': 65,
#   'Cloudiness': 83,
#   'Wind Speed': 9.31,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:02:23'},
#  {'City': 'Chabahar',
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp': 85.78,
#   'Humidity': 53,
#   'Cloudiness': 41,
#   'Wind Speed': 10.09,
#   'Country': 'IR',
#   'Date': '2022-04-16 18:02:24'},
#  {'City': 'Sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 46.36,
#   'Humidity': 84,
#   'Cloudiness': 57,
#   'Wind Speed': 7.23,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:02:24'},
#  {'City': 'Nizwa',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 88.72,
#   'Humidity': 16,
#   'Cloudiness': 68,
#   'Wind Speed': 5.35,
#   'Country': 'OM',
#   'Date': '2022-04-16 18:02:25'},
#  {'City': 'Urubicha',
#   'Lat': -15.3833,
#   'Lng': -62.95,
#   'Max Temp': 88,
#   'Humidity': 37,
#   'Cloudiness': 2,
#   'Wind Speed': 2.82,
#   'Country': 'BO',
#   'Date': '2022-04-16 18:02:25'},
#  {'City': 'Hammerfest',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 39.65,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:02:26'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75.7,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 7.43,
#   'Country': 'PT',
#   'Date': '2022-04-16 18:02:26'},
#  {'City': 'Bushehr',
#   'Lat': 28.9684,
#   'Lng': 50.8385,
#   'Max Temp': 78.89,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Date': '2022-04-16 17:57:40'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 84.34,
#   'Humidity': 26,
#   'Cloudiness': 73,
#   'Wind Speed': 12.28,
#   'Country': 'SA',
#   'Date': '2022-04-16 17:57:32'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.05,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Date': '2022-04-16 18:02:27'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 93.81,
#   'Humidity': 18,
#   'Cloudiness': 18,
#   'Wind Speed': 1.77,
#   'Country': 'TD',
#   'Date': '2022-04-16 18:02:27'},
#  {'City': 'Sarny',
#   'Lat': 51.338,
#   'Lng': 26.6019,
#   'Max Temp': 37.8,
#   'Humidity': 73,
#   'Cloudiness': 78,
#   'Wind Speed': 12.55,
#   'Country': 'UA',
#   'Date': '2022-04-16 18:02:27'},
#  {'City': 'Mwene-Ditu',
#   'Lat': -7,
#   'Lng': 23.45,
#   'Max Temp': 68.86,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 1.97,
#   'Country': 'CD',
#   'Date': '2022-04-16 18:02:28'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 62.92,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 8.77,
#   'Country': 'CL',
#   'Date': '2022-04-16 18:01:43'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 72.1,
#   'Humidity': 77,
#   'Cloudiness': 5,
#   'Wind Speed': 14.23,
#   'Country': 'CV',
#   'Date': '2022-04-16 18:02:29'},
#  {'City': 'Sol-Iletsk',
#   'Lat': 51.1631,
#   'Lng': 54.9918,
#   'Max Temp': 47.19,
#   'Humidity': 59,
#   'Cloudiness': 9,
#   'Wind Speed': 7.02,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:02:29'},
#  {'City': 'Abaza',
#   'Lat': 52.655,
#   'Lng': 90.0928,
#   'Max Temp': 43.56,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 5.08,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:02:29'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 91.38,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:02:30'},
#  {'City': 'Johannesburg',
#   'Lat': -26.2023,
#   'Lng': 28.0436,
#   'Max Temp': 53.15,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Date': '2022-04-16 18:02:30'},
#  {'City': 'Vossevangen',
#   'Lat': 60.623,
#   'Lng': 6.4229,
#   'Max Temp': 39.29,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:02:31'},
#  {'City': 'Buchanan',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 82.33,
#   'Humidity': 77,
#   'Cloudiness': 76,
#   'Wind Speed': 7.38,
#   'Country': 'LR',
#   'Date': '2022-04-16 18:02:31'},
#  {'City': 'Trinidad',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 83.8,
#   'Humidity': 46,
#   'Cloudiness': 2,
#   'Wind Speed': 4.5,
#   'Country': 'BO',
#   'Date': '2022-04-16 18:02:31'},
#  {'City': 'Vienna',
#   'Lat': 48.2085,
#   'Lng': 16.3721,
#   'Max Temp': 48.69,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'AT',
#   'Date': '2022-04-16 18:02:10'},
#  {'City': 'Santa Maria Do Suacui',
#   'Lat': -18.1903,
#   'Lng': -42.4142,
#   'Max Temp': 73.45,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 5.61,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:03:32'},
#  {'City': 'Vagur',
#   'Lat': 61.4732,
#   'Lng': -6.8119,
#   'Max Temp': 47.75,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 22.82,
#   'Country': 'FO',
#   'Date': '2022-04-16 18:03:32'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 61.48,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-04-16 18:03:27'},
#  {'City': 'Igrim',
#   'Lat': 63.1906,
#   'Lng': 64.4162,
#   'Max Temp': 25.21,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:03:33'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.85,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 3.29,
#   'Country': 'ID',
#   'Date': '2022-04-16 18:03:33'},
#  {'City': 'Sal Rei',
#   'Lat': 16.1833,
#   'Lng': -22.9167,
#   'Max Temp': 73.6,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'CV',
#   'Date': '2022-04-16 18:03:34'},
#  {'City': 'Miandrivazo',
#   'Lat': -19.5167,
#   'Lng': 45.4667,
#   'Max Temp': 81.55,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 3.91,
#   'Country': 'MG',
#   'Date': '2022-04-16 18:03:34'},
#  {'City': 'Store Heddinge',
#   'Lat': 55.3097,
#   'Lng': 12.3889,
#   'Max Temp': 49.68,
#   'Humidity': 65,
#   'Cloudiness': 39,
#   'Wind Speed': 5.91,
#   'Country': 'DK',
#   'Date': '2022-04-16 18:03:34'},
#  {'City': 'Oschatz',
#   'Lat': 51.3,
#   'Lng': 13.1167,
#   'Max Temp': 47.52,
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 4.99,
#   'Country': 'DE',
#   'Date': '2022-04-16 18:03:35'},
#  {'City': 'Xacmaz',
#   'Lat': 41.4635,
#   'Lng': 48.806,
#   'Max Temp': 49.33,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'AZ',
#   'Date': '2022-04-16 18:03:35'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 80.69,
#   'Humidity': 61,
#   'Cloudiness': 37,
#   'Wind Speed': 16.4,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:03:36'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 82.26,
#   'Humidity': 28,
#   'Cloudiness': 83,
#   'Wind Speed': 11.23,
#   'Country': 'SA',
#   'Date': '2022-04-16 18:03:36'},
#  {'City': 'Bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 82.31,
#   'Humidity': 62,
#   'Cloudiness': 39,
#   'Wind Speed': 13.96,
#   'Country': 'SL',
#   'Date': '2022-04-16 18:03:36'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 65.95,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'ES',
#   'Date': '2022-04-16 18:03:37'},
#  {'City': 'Sanandaj',
#   'Lat': 35.3144,
#   'Lng': 46.9923,
#   'Max Temp': 57.22,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'IR',
#   'Date': '2022-04-16 17:55:44'},
#  {'City': 'Limon',
#   'Lat': 10,
#   'Lng': -83.0333,
#   'Max Temp': 82.29,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'CR',
#   'Date': '2022-04-16 18:03:37'},
#  {'City': 'Kajaani',
#   'Lat': 64.2273,
#   'Lng': 27.7285,
#   'Max Temp': 37.45,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'FI',
#   'Date': '2022-04-16 18:03:38'},
#  {'City': 'Marquette',
#   'Lat': 46.5333,
#   'Lng': -87.6335,
#   'Max Temp': 26.78,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 13.06,
#   'Country': 'US',
#   'Date': '2022-04-16 18:03:38'},
#  {'City': 'Lethem',
#   'Lat': 3.3803,
#   'Lng': -59.7968,
#   'Max Temp': 92.64,
#   'Humidity': 41,
#   'Cloudiness': 97,
# ...
#   'Country': 'BR',
#   'Date': '2022-04-16 18:10:12'},
#  {'City': 'Bosaso',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 83.1,
#   'Humidity': 73,
#   'Cloudiness': 7,
#   'Wind Speed': 2.15,
#   'Country': 'SO',
#   'Date': '2022-04-16 18:10:13'},
#  {'City': 'Visnes',
#   'Lat': 59.3556,
#   'Lng': 5.2242,
#   'Max Temp': 46.81,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:10:13'},
#  {'City': 'Suoyarvi',
#   'Lat': 62.0833,
#   'Lng': 32.35,
#   'Max Temp': 27.99,
#   'Humidity': 92,
#   'Cloudiness': 93,
#   'Wind Speed': 0.67,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:10:14'},
#  {'City': 'Pascagoula',
#   'Lat': 30.3658,
#   'Lng': -88.5561,
#   'Max Temp': 86.56,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 8.32,
#   'Country': 'US',
#   'Date': '2022-04-16 18:10:14'},
#  {'City': 'Sompeta',
#   'Lat': 18.9333,
#   'Lng': 84.6,
#   'Max Temp': 81.12,
#   'Humidity': 64,
#   'Cloudiness': 78,
#   'Wind Speed': 11.83,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:07:20'},
#  {'City': 'Kibala',
#   'Lat': 9.1104,
#   'Lng': 18.3463,
#   'Max Temp': 95.11,
#   'Humidity': 24,
#   'Cloudiness': 27,
#   'Wind Speed': 4.14,
#   'Country': 'TD',
#   'Date': '2022-04-16 18:10:15'},
#  {'City': 'Mangan',
#   'Lat': 27.5167,
#   'Lng': 88.5333,
#   'Max Temp': 65.44,
#   'Humidity': 67,
#   'Cloudiness': 58,
#   'Wind Speed': 7.09,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:10:15'},
#  {'City': 'Dalbandin',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp': 84.96,
#   'Humidity': 16,
#   'Cloudiness': 92,
#   'Wind Speed': 5.61,
#   'Country': 'PK',
#   'Date': '2022-04-16 18:10:15'},
#  {'City': 'Gambela',
#   'Lat': 8.25,
#   'Lng': 34.5833,
#   'Max Temp': 74.21,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'ET',
#   'Date': '2022-04-16 18:10:16'},
#  {'City': 'Gayeri',
#   'Lat': 12.6497,
#   'Lng': 0.4931,
#   'Max Temp': 91.31,
#   'Humidity': 32,
#   'Cloudiness': 99,
#   'Wind Speed': 16.11,
#   'Country': 'BF',
#   'Date': '2022-04-16 18:10:16'},
#  {'City': 'Canakkale',
#   'Lat': 40.0833,
#   'Lng': 26.8333,
#   'Max Temp': 55.98,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 1.45,
#   'Country': 'TR',
#   'Date': '2022-04-16 18:10:16'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 63.07,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Date': '2022-04-16 18:10:17'},
#  {'City': 'Weymouth',
#   'Lat': 42.2209,
#   'Lng': -70.9398,
#   'Max Temp': 71.47,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 25.32,
#   'Country': 'US',
#   'Date': '2022-04-16 18:10:17'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 8.24,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 4.29,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:10:18'},
#  {'City': 'Abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 66.45,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'SA',
#   'Date': '2022-04-16 18:05:42'},
#  {'City': 'Maiduguri',
#   'Lat': 11.8464,
#   'Lng': 13.1603,
#   'Max Temp': 97.66,
#   'Humidity': 24,
#   'Cloudiness': 66,
#   'Wind Speed': 4.68,
#   'Country': 'NG',
#   'Date': '2022-04-16 18:10:18'},
#  {'City': 'Lakota',
#   'Lat': 5.8528,
#   'Lng': -5.6883,
#   'Max Temp': 77.32,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Country': 'CI',
#   'Date': '2022-04-16 18:10:19'},
#  {'City': 'Naryan-Mar',
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 8.58,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:10:19'},
#  {'City': 'Penzance',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 58.32,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'GB',
#   'Date': '2022-04-16 18:10:20'},
#  {'City': 'Shemursha',
#   'Lat': 54.8866,
#   'Lng': 47.5189,
#   'Max Temp': 38.35,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 14.94,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:10:20'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79.2,
#   'Humidity': 81,
#   'Cloudiness': 15,
#   'Wind Speed': 7,
#   'Country': 'MU',
#   'Date': '2022-04-16 18:11:20'},
#  {'City': 'Varkkallai',
#   'Lat': 8.7341,
#   'Lng': 76.7067,
#   'Max Temp': 85.78,
#   'Humidity': 79,
#   'Cloudiness': 63,
#   'Wind Speed': 4.41,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:08:05'},
#  {'City': 'Tshikapa',
#   'Lat': -6.4167,
#   'Lng': 20.8,
#   'Max Temp': 75.58,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 2.68,
#   'Country': 'CD',
#   'Date': '2022-04-16 18:11:21'},
#  {'City': 'Trelew',
#   'Lat': -43.249,
#   'Lng': -65.3051,
#   'Max Temp': 63.5,
#   'Humidity': 37,
#   'Cloudiness': 3,
#   'Wind Speed': 11.65,
#   'Country': 'AR',
#   'Date': '2022-04-16 18:08:31'},
#  {'City': 'Dimitrovgrad',
#   'Lat': 54.2139,
#   'Lng': 49.6184,
#   'Max Temp': 41.68,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 7.94,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:22'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 78.91,
#   'Humidity': 81,
#   'Cloudiness': 53,
#   'Wind Speed': 15.5,
#   'Country': 'MU',
#   'Date': '2022-04-16 18:11:22'},
#  {'City': 'Rognan',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 43.88,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:11:23'},
#  {'City': 'Bindura',
#   'Lat': -17.3019,
#   'Lng': 31.3306,
#   'Max Temp': 70.77,
#   'Humidity': 62,
#   'Cloudiness': 93,
#   'Wind Speed': 5.57,
#   'Country': 'ZW',
#   'Date': '2022-04-16 18:11:23'},
#  {'City': 'Mirabad',
#   'Lat': 30.4362,
#   'Lng': 61.8383,
#   'Max Temp': 82.26,
#   'Humidity': 23,
#   'Cloudiness': 92,
#   'Wind Speed': 16.11,
#   'Country': 'AF',
#   'Date': '2022-04-16 18:11:24'},
#  {'City': 'La Palma',
#   'Lat': 33.8464,
#   'Lng': -118.0467,
#   'Max Temp': 67.77,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2022-04-16 18:11:24'},
#  {'City': 'Akdepe',
#   'Lat': 42.0551,
#   'Lng': 59.3788,
#   'Max Temp': 59.31,
#   'Humidity': 49,
#   'Cloudiness': 80,
#   'Wind Speed': 12.88,
#   'Country': 'TM',
#   'Date': '2022-04-16 18:11:25'},
#  {'City': 'Trairi',
#   'Lat': -3.2778,
#   'Lng': -39.2689,
#   'Max Temp': 83.07,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 7.2,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:11:25'},
#  {'City': 'Oussouye',
#   'Lat': 12.485,
#   'Lng': -16.5469,
#   'Max Temp': 86.18,
#   'Humidity': 47,
#   'Cloudiness': 15,
#   'Wind Speed': 15.95,
#   'Country': 'SN',
#   'Date': '2022-04-16 18:11:26'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 83.05,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 6.13,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:11:26'},
#  {'City': 'Montgomery',
#   'Lat': 39.1501,
#   'Lng': -77.1997,
#   'Max Temp': 78.55,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2022-04-16 18:11:27'},
#  {'City': 'Cerrito',
#   'Lat': 6.8432,
#   'Lng': -72.694,
#   'Max Temp': 63.66,
#   'Humidity': 75,
#   'Cloudiness': 79,
#   'Wind Speed': 0.76,
#   'Country': 'CO',
#   'Date': '2022-04-16 18:11:27'},
#  {'City': 'Kachiry',
#   'Lat': 53.0675,
#   'Lng': 76.1036,
#   'Max Temp': 60.12,
#   'Humidity': 37,
#   'Cloudiness': 83,
#   'Wind Speed': 5.68,
#   'Country': 'KZ',
#   'Date': '2022-04-16 18:11:28'},
#  {'City': 'Nizhnyaya Omka',
#   'Lat': 55.4338,
#   'Lng': 74.9426,
#   'Max Temp': 57.38,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:28'},
#  {'City': 'Takestan',
#   'Lat': 36.0696,
#   'Lng': 49.6959,
#   'Max Temp': 41.63,
#   'Humidity': 72,
#   'Cloudiness': 64,
#   'Wind Speed': 14.25,
#   'Country': 'IR',
#   'Date': '2022-04-16 18:11:28'},
#  {'City': 'Kilindoni',
#   'Lat': -7.9139,
#   'Lng': 39.6668,
#   'Max Temp': 81.77,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 14.67,
#   'Country': 'TZ',
#   'Date': '2022-04-16 18:11:29'},
#  {'City': 'Lokosovo',
#   'Lat': 61.1333,
#   'Lng': 74.8167,
#   'Max Temp': 32.59,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.27,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:29'},
#  {'City': 'Natal',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 88.45,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:11:30'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 77.36,
#   'Humidity': 85,
#   'Cloudiness': 3,
#   'Wind Speed': 12.64,
#   'Country': 'MG',
#   'Date': '2022-04-16 18:11:30'},
#  {'City': 'Murgab',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 67.37,
#   'Humidity': 39,
#   'Cloudiness': 65,
#   'Wind Speed': 8.95,
#   'Country': 'TM',
#   'Date': '2022-04-16 18:11:31'},
#  {'City': 'Yarada',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 84.52,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:11:31'},
#  {'City': 'Harda',
#   'Lat': 22.3333,
#   'Lng': 77.1,
#   'Max Temp': 89.85,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 7.29,
#   'Country': 'IN',
#   'Date': '2022-04-16 18:11:32'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 59.65,
#   'Humidity': 75,
#   'Cloudiness': 21,
#   'Wind Speed': 10.45,
#   'Country': 'ZA',
#   'Date': '2022-04-16 18:11:32'},
#  {'City': 'Storforshei',
#   'Lat': 66.4043,
#   'Lng': 14.5233,
#   'Max Temp': 39.65,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'NO',
#   'Date': '2022-04-16 18:11:33'},
#  {'City': 'George Town',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.33,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2022-04-16 18:08:07'},
#  {'City': 'La Carolina',
#   'Lat': 38.2756,
#   'Lng': -3.6153,
#   'Max Temp': 71.83,
#   'Humidity': 41,
#   'Cloudiness': 16,
#   'Wind Speed': 4.38,
#   'Country': 'ES',
#   'Date': '2022-04-16 18:11:33'},
#  {'City': 'Paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 74.91,
#   'Humidity': 69,
#   'Cloudiness': 53,
#   'Wind Speed': 14.32,
#   'Country': 'PE',
#   'Date': '2022-04-16 18:11:33'},
#  {'City': 'Cameta',
#   'Lat': -2.2444,
#   'Lng': -49.4958,
#   'Max Temp': 83.91,
#   'Humidity': 75,
#   'Cloudiness': 56,
#   'Wind Speed': 4.76,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:11:34'},
#  {'City': 'Coxim',
#   'Lat': -18.5067,
#   'Lng': -54.76,
#   'Max Temp': 85.39,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 6.11,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:11:34'},
#  {'City': 'Santiago',
#   'Lat': -33.4569,
#   'Lng': -70.6483,
#   'Max Temp': 79.29,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Date': '2022-04-16 18:10:22'},
#  {'City': 'Melfi',
#   'Lat': 40.9965,
#   'Lng': 15.6514,
#   'Max Temp': 49.64,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Country': 'IT',
#   'Date': '2022-04-16 18:11:35'},
#  {'City': 'Amantea',
#   'Lat': 39.1332,
#   'Lng': 16.0746,
#   'Max Temp': 63.16,
#   'Humidity': 62,
#   'Cloudiness': 98,
#   'Wind Speed': 6.04,
#   'Country': 'IT',
#   'Date': '2022-04-16 18:11:35'},
#  {'City': 'Blagoyevo',
#   'Lat': 63.3667,
#   'Lng': 47.9167,
#   'Max Temp': 20.64,
#   'Humidity': 95,
#   'Cloudiness': 53,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:36'},
#  {'City': 'Lydenburg',
#   'Lat': -25.0978,
#   'Lng': 30.4597,
#   'Max Temp': 54.5,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Country': 'ZA',
#   'Date': '2022-04-16 18:11:36'},
#  {'City': 'Arnsberg',
#   'Lat': 51.3297,
#   'Lng': 8.0071,
#   'Max Temp': 53.1,
#   'Humidity': 60,
#   'Cloudiness': 27,
#   'Wind Speed': 5.53,
#   'Country': 'DE',
#   'Date': '2022-04-16 18:11:36'},
#  {'City': 'Ambanja',
#   'Lat': -13.6833,
#   'Lng': 48.45,
#   'Max Temp': 76.96,
#   'Humidity': 90,
#   'Cloudiness': 24,
#   'Wind Speed': 2.71,
#   'Country': 'MG',
#   'Date': '2022-04-16 18:11:37'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 40.89,
#   'Humidity': 45,
#   'Cloudiness': 24,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:37'},
#  {'City': 'Bani Walid',
#   'Lat': 31.7566,
#   'Lng': 13.9942,
#   'Max Temp': 66.54,
#   'Humidity': 50,
#   'Cloudiness': 43,
#   'Wind Speed': 20.78,
#   'Country': 'LY',
#   'Date': '2022-04-16 18:11:38'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 51.21,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 11.45,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:11:38'},
#  {'City': 'Fonte Boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 79.05,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 4.72,
#   'Country': 'BR',
#   'Date': '2022-04-16 18:12:39'},
#  {'City': 'Milas',
#   'Lat': 37.3164,
#   'Lng': 27.7839,
#   'Max Temp': 67.35,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'TR',
#   'Date': '2022-04-16 18:11:53'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 74.71,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.86,
#   'Country': 'PT',
#   'Date': '2022-04-16 18:12:39'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 80.96,
#   'Humidity': 79,
#   'Cloudiness': 71,
#   'Wind Speed': 8.12,
#   'Country': 'LR',
#   'Date': '2022-04-16 18:12:40'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 82.49,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'OM',
#   'Date': '2022-04-16 18:12:40'},
#  {'City': 'Verkhniy Lomov',
#   'Lat': 53.4678,
#   'Lng': 43.5511,
#   'Max Temp': 50.85,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 16.58,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:12:40'},
#  {'City': 'Trebinje',
#   'Lat': 42.7119,
#   'Lng': 18.3442,
#   'Max Temp': 64.74,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Country': 'BA',
#   'Date': '2022-04-16 18:09:30'},
#  {'City': 'Hvide Sande',
#   'Lat': 56.0045,
#   'Lng': 8.1294,
#   'Max Temp': 47.08,
#   'Humidity': 68,
#   'Cloudiness': 65,
#   'Wind Speed': 4.21,
#   'Country': 'DK',
#   'Date': '2022-04-16 18:12:41'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.61,
#   'Humidity': 77,
#   'Cloudiness': 86,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2022-04-16 18:12:42'},
#  {'City': 'Rurrenabaque',
#   'Lat': -14.4413,
#   'Lng': -67.5278,
#   'Max Temp': 88.05,
#   'Humidity': 40,
#   'Cloudiness': 5,
#   'Wind Speed': 3.15,
#   'Country': 'BO',
#   'Date': '2022-04-16 18:12:42'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 68.5,
#   'Humidity': 94,
#   'Cloudiness': 54,
#   'Wind Speed': 0.87,
#   'Country': 'PH',
#   'Date': '2022-04-16 18:08:12'},
#  {'City': 'Malanje',
#   'Lat': -9.5402,
#   'Lng': 16.341,
#   'Max Temp': 66.6,
#   'Humidity': 93,
#   'Cloudiness': 43,
#   'Wind Speed': 2.51,
#   'Country': 'AO',
#   'Date': '2022-04-16 18:12:42'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 78.91,
#   'Humidity': 88,
#   'Cloudiness': 34,
#   'Wind Speed': 5.23,
#   'Country': 'GA',
#   'Date': '2022-04-16 18:12:43'},
#  {'City': 'Beyneu',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 61.83,
#   'Humidity': 35,
#   'Cloudiness': 10,
#   'Wind Speed': 5.97,
#   'Country': 'KZ',
#   'Date': '2022-04-16 18:12:43'},
#  {'City': 'Grand Baie',
#   'Lat': -20.0182,
#   'Lng': 57.5802,
#   'Max Temp': 79.27,
#   'Humidity': 81,
#   'Cloudiness': 12,
#   'Wind Speed': 7,
#   'Country': 'MU',
#   'Date': '2022-04-16 18:12:44'},
#  {'City': 'Normandin',
#   'Lat': 48.8333,
#   'Lng': -72.5321,
#   'Max Temp': 37.53,
#   'Humidity': 52,
#   'Cloudiness': 43,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': '2022-04-16 18:12:44'},
#  {'City': 'Pomabamba',
#   'Lat': -8.8333,
#   'Lng': -77.4667,
#   'Max Temp': 64.56,
#   'Humidity': 43,
#   'Cloudiness': 93,
#   'Wind Speed': 6.08,
#   'Country': 'PE',
#   'Date': '2022-04-16 18:12:45'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 64.04,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'CL',
#   'Date': '2022-04-16 18:12:45'},
#  {'City': 'Puerto Ayacucho',
#   'Lat': 5.6639,
#   'Lng': -67.6236,
#   'Max Temp': 81.23,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'VE',
#   'Date': '2022-04-16 18:12:46'},
#  {'City': 'Ugra',
#   'Lat': 54.7777,
#   'Lng': 34.3267,
#   'Max Temp': 35.1,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'RU',
#   'Date': '2022-04-16 18:12:46'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kribi   2.9500   9.9167     80.69        85          83
# 1      Walvis Bay -22.9575  14.5053     59.95        82          13
# 2          Abalak  58.1286  68.5944     41.04        91          95
# 3      Bar-Le-Duc  48.7500   5.1667     61.18        71           1
# 4          Kibaya  -5.3000  36.5667     59.85        99         100
# 5  Saint-Philippe -21.3585  55.7679     76.59        80          51
# 6       Raudeberg  61.9875   5.1352     47.07        70          99
# 7       Hithadhoo  -0.6000  73.0833     83.52        65          96
# 8           Ginir   7.1333  40.7000     61.05        84          98
# 9   Puerto Madryn -42.7692 -65.0385     62.71        44           2
#
#    Wind Speed Country                 Date
# 0       10.18      CM  2022-04-16 17:57:12
# 1        6.91      NA  2022-04-16 17:57:13
# 2       11.27      RU  2022-04-16 17:57:13
# 3       12.73      FR  2022-04-16 17:57:14
# 4        0.81      TZ  2022-04-16 17:57:14
# 5       14.25      RE  2022-04-16 17:48:00
# 6       21.54      NO  2022-04-16 17:57:14
# 7        3.74      MV  2022-04-16 17:57:15
# 8        5.48      ET  2022-04-16 17:57:15
# 9       12.50      AR  2022-04-16 17:57:16

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time

# Get today's date in seconds.
today = time.time()
today
# Out:
# 1650132766.787306

# %%
# Get today's date
today = time.strftime("%x")
today
# Out:
# '04/16/22'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt

# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)

# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")

# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Perform linear regression.
# (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
# regress_values = x_values * slope + intercept

# Get the equation of the line.
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
# plt.scatter(x_values,y_values)

# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
# plt.plot(x_values,regress_values,"r")

# Annotate the text for the line equation and add its coordinates.
# plt.annotate(line_eq, (10,40), fontsize=15, color="red")
# plt.title(title)
# plt.xlabel('Latitude')
# plt.ylabel('Temp')
# plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
# def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Kribi   2.9500    9.9167     80.69        85          83
# 2             Abalak  58.1286   68.5944     41.04        91          95
# 3         Bar-Le-Duc  48.7500    5.1667     61.18        71           1
# 6          Raudeberg  61.9875    5.1352     47.07        70          99
# 8              Ginir   7.1333   40.7000     61.05        84          98
# ..               ...      ...       ...       ...       ...         ...
# 566           Marawi   7.9986  124.2928     68.50        94          54
# 569           Beyneu  45.3167   55.2000     61.83        35          10
# 571        Normandin  48.8333  -72.5321     37.53        52          43
# 574  Puerto Ayacucho   5.6639  -67.6236     81.23        74         100
# 575             Ugra  54.7777   34.3267     35.10        90         100
#
#      Wind Speed Country                 Date
# 0         10.18      CM  2022-04-16 17:57:12
# 2         11.27      RU  2022-04-16 17:57:13
# 3         12.73      FR  2022-04-16 17:57:14
# 6         21.54      NO  2022-04-16 17:57:14
# 8          5.48      ET  2022-04-16 17:57:15
# ..          ...     ...                  ...
# 566        0.87      PH  2022-04-16 18:08:12
# 569        5.97      KZ  2022-04-16 18:12:43
# 571       14.97      CA  2022-04-16 18:12:44
# 574        6.49      VE  2022-04-16 18:12:46
# 575       11.68      RU  2022-04-16 18:12:46
#
# [401 rows x 9 columns]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Kribi   2.9500   9.9167     80.69        85          83       10.18
# 2      Abalak  58.1286  68.5944     41.04        91          95       11.27
# 3  Bar-Le-Duc  48.7500   5.1667     61.18        71           1       12.73
# 6   Raudeberg  61.9875   5.1352     47.07        70          99       21.54
# 8       Ginir   7.1333  40.7000     61.05        84          98        5.48
#
#   Country                 Date
# 0      CM  2022-04-16 17:57:12
# 2      RU  2022-04-16 17:57:13
# 3      FR  2022-04-16 17:57:14
# 6      NO  2022-04-16 17:57:14
# 8      ET  2022-04-16 17:57:15

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression, Percent Cloudiness for the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
